# %% [markdown]
# # **CHAPTER 3 - CLASSIFICATION**

# %% [markdown]
# ## **THIS CHAPTER WILL WORK WITH MNIST DATASET**

# %%
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784',as_frame=False)
# Out:
# c:\Users\Nikhil\OneDrive\Desktop\MY PERSONAL WORK\DATA SCIENCE\Hand on ML\Hand-on-Machine-Learning-with-Scikit-Learn-Keras-Tensorflow\handsonmlenv\Lib\site-packages\sklearn\datasets\_openml.py:74: RuntimeWarning: Invalid cache, redownloading file
#   warn("Invalid cache, redownloading file", RuntimeWarning)
